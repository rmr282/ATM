# %%
from collections import Counter
from collections import defaultdict
import numpy as np
import pandas as pd
import spacy
from nltk import word_tokenize
import string

from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
from stanza.pipeline.processor import ProcessorVariant, register_processor_variant

# %%
# load data
data = pd.read_csv('SEM-2012-SharedTask-CD-SCO-training-simple.v2.txt', sep="\t", header=None)
data.columns = ['annotator', 'sentence_id', 'token_id', 'token', 'label']

# %%
nlp = spacy.load("en_core_web_sm")

# %%
punctuations = string.punctuation
punctuations = punctuations.replace("'", '')
punctuations = punctuations.replace('`', '')

# %%
annotator_ids = data["annotator"].unique()
TOTAL_SENTENCES = []
# print(annotator_ids)
for annotator in annotator_ids:
    temp = data.loc[data["annotator"]==annotator]
    list_sentences = temp['sentence_id'].unique()
    # print(list_sentences)
    for sentence in list_sentences:
        temp2 = temp.loc[temp['sentence_id'] == sentence]
        tokens = ' '.join(list(temp2['token']))
        ## REMOVE PUNCTUATION EXCEPT APOSTROPHE
        tokens = " ".join("".join([" " if ch in punctuations else ch for ch in tokens]).split())
        TOTAL_SENTENCES.append(tokens)

# %%
print('Number of Sentences:', len(TOTAL_SENTENCES))
print('Number of tokens:', len(data['token']))
# Out:
# Number of Sentences: 3644
# Number of words: 65451

# %%
# Counting the frequencies of the words 
word_frequencies = Counter()
total_length = 0

# To count the number of tokens 
num_tokens = 0
pos_tokencounts_dict = defaultdict(Counter)

annotator_ids = data["annotator"].unique()

for annotator in annotator_ids:
    temp = data.loc[data['annotator'] == annotator]
    list_sentences = pd.unique(data[['sentence_id']].values.ravel())

    for sentence in list_sentences:
        words = []
        pos_list = []
        tag_list = []
        temp2 = temp.loc[temp['sentence_id'] == sentence]

        tokens = ' '.join(list(temp2['token']))
        tokens = " ".join("".join([" " if ch in punctuations else ch for ch in tokens]).split())
        doc = nlp(tokens)
        prev = None
        prev_lemma = []
        lemmas = []
        for token in doc:
            num_tokens += 1
            prev_lemma = prev
            lemmas.append(token.lemma_)
            if not token.is_punct:
                total_length += len(token)
                tags_tp = (token.tag_,token.pos_)
                pos_tokencounts_dict[tags_tp].update([token.text])
                words.append(token.text)
        word_frequencies.update(words)

# %%
# Number of words 
num_words = sum(word_frequencies.values())
print('Number of words:', num_words)

# Number of word types 
num_types = len(word_frequencies.keys())
print('Number of word types:', num_types)
# Average words per sentence 

avg_words_sen = num_words/len(TOTAL_SENTENCES)
print('Average words per sentence:', avg_words_sen)

# Average word length 
avg_word_length = total_length / num_words
print('Average word length', avg_word_length)
# Out:
# Number of words: 58577
# Number of word types: 5673
# Average words per sentence: 16.074917672886937
# Average word length 3.942929818870888

# %%
pos_tokencounts_dict
# Out:
# defaultdict(collections.Counter,
#             {('NN',
#               'NOUN'): Counter({'Chapter': 14,
#                       'night': 70,
#                       'breakfast': 11,
#                       'table': 10,
#                       'hearth': 2,
#                       'rug': 1,
#                       'stick': 13,
#                       'visitor': 10,
#                       'piece': 3,
#                       'wood': 4,
#                       'sort': 8,
#                       'lawyer': 2,
#                       'head': 30,
#                       'silver': 6,
#                       'band': 2,
#                       'inch': 4,
#                       'date': 12,
#                       'family': 34,
#                       'practitioner': 6,
#                       'back': 8,
#                       'sign': 9,
#                       'occupation': 1,
#                       'coffee': 5,
#                       'pot': 1,
#                       'front': 23,
#                       'notion': 1,
#                       'errand': 4,
#                       'souvenir': 1,
#                       'importance': 9,
#                       'man': 195,
#                       'examination': 3,
#                       'companion': 10,
#                       'mark': 8,
#                       'appreciation': 2,
#                       'probability': 6,
#                       'favour': 5,
#                       'country': 19,
#                       'deal': 10,
#                       'foot': 9,
#                       'one': 46,
#                       'town': 12,
#                       'iron': 4,
#                       'ferrule': 1,
#                       'amount': 2,
#                       'hunt': 6,
#                       'assistance': 4,
#                       'presentation': 6,
#                       'return': 7,
#                       'chair': 8,
#                       'cigarette': 6,
#                       'conductor': 1,
#                       'light': 49,
#                       'genius': 1,
#                       'power': 11,
#                       'fellow': 31,
#                       'debt': 1,
#                       'pleasure': 9,
#                       'indifference': 3,
#                       'admiration': 3,
#                       'publicity': 1,
#                       'system': 2,
#                       'way': 53,
#                       'approval': 1,
#                       'expression': 11,
#                       'interest': 21,
#                       'cane': 2,
#                       'window': 36,
#                       'lens': 2,
#                       'corner': 9,
#                       'settee': 2,
#                       'basis': 3,
#                       'self': 4,
#                       'consequence': 3,
#                       'truth': 20,
#                       'instance': 3,
#                       'extent': 3,
#                       'means': 3,
#                       'example': 10,
#                       'doctor': 6,
#                       'hospital': 7,
#                       'direction': 21,
#                       'hypothesis': 2,
#                       'construction': 1,
#                       'none': 9,
#                       'conclusion': 5,
#                       'occasion': 8,
#                       'pledge': 2,
#                       'will': 8,
#                       'moment': 24,
#                       'service': 6,
#                       'order': 8,
#                       'practice': 6,
#                       'change': 5,
#                       'inference': 1,
#                       'staff': 4,
#                       'position': 15,
#                       'house': 56,
#                       'surgeon': 1,
#                       'physician': 1,
#                       'student': 1,
#                       'grave': 4,
#                       'middle': 9,
#                       'air': 17,
#                       'possessor': 1,
#                       'dog': 17,
#                       'terrier': 1,
#                       'mastiff': 3,
#                       'wavering': 1,
#                       'smoke': 7,
#                       'ceiling': 2,
#                       'part': 14,
#                       'age': 7,
#                       'career': 3,
#                       'shelf': 1,
#                       'name': 35,
#                       'record': 1,
#                       'aloud': 1,
#                       'Mortimer': 5,
#                       'House': 2,
#                       'Winner': 1,
#                       'prize': 1,
#                       'essay': 1,
#                       'member': 2,
#                       'Author': 1,
#                       'mention': 1,
#                       'smile': 5,
#                       'experience': 7,
#                       'world': 20,
#                       'card': 3,
#                       'hour': 20,
#                       'room': 35,
#                       'habit': 4,
#                       'master': 12,
#                       'jaw': 2,
#                       'space': 6,
#                       'opinion': 6,
#                       'spaniel': 5,
#                       'recess': 2,
#                       'ring': 4,
#                       'conviction': 3,
#                       'voice': 21,
#                       'surprise': 14,
#                       'reason': 18,
#                       'door': 37,
#                       'step': 9,
#                       'owner': 5,
#                       'brother': 25,
#                       'presence': 8,
#                       'fate': 5,
#                       'stair': 4,
#                       'life': 33,
#                       'science': 6,
#                       'specialist': 1,
#                       'crime': 9,
#                       'appearance': 9,
#                       'nose': 1,
#                       'beak': 1,
#                       'pair': 11,
#                       'gold': 4,
#                       'fashion': 4,
#                       'frock': 2,
#                       'coat': 4,
#                       'thrust': 1,
#                       'benevolence': 1,
#                       'hand': 35,
#                       'exclamation': 4,
#                       'joy': 5,
#                       'sir': 102,
#                       'marriage': 5,
#                       'astonishment': 2,
#                       'consulting': 2,
#                       'home': 10,
#                       'Mister': 1,
#                       'mind': 35,
#                       'dabbler': 1,
#                       'picker': 1,
#                       'ocean': 1,
#                       'friend': 60,
#                       'connection': 12,
#                       'skull': 9,
#                       'supra': 2,
#                       'development': 2,
#                       'objection': 2,
#                       'finger': 3,
#                       'fissure': 1,
#                       'cast': 1,
#                       'original': 1,
#                       'museum': 2,
#                       'intention': 4,
#                       'enthusiast': 2,
#                       'line': 12,
#                       'thought': 13,
#                       'forefinger': 1,
#                       'hesitation': 2,
#                       'paper': 21,
#                       'tobacco': 5,
#                       'dexterity': 1,
#                       'antennae': 1,
#                       'insect': 1,
#                       'purpose': 8,
#                       'honour': 3,
#                       'today': 10,
#                       'opportunity': 5,
#                       'problem': 7,
#                       'expert': 4,
#                       'asperity': 1,
#                       'work': 14,
#                       'ado': 1,
#                       'nature': 9,
#                       'pocket': 10,
#                       'manuscript': 5,
#                       'century': 1,
#                       'forgery': 1,
#                       'time': 78,
#                       'document': 3,
#                       'decade': 1,
#                       'monograph': 1,
#                       'subject': 4,
#                       'breast': 2,
#                       'care': 4,
#                       'death': 52,
#                       'excitement': 5,
#                       'attendant': 3,
#                       'end': 28,
#                       'knee': 3,
#                       'use': 7,
#                       's': 1,
#                       'shoulder': 7,
#                       'script': 1,
#                       'statement': 5,
#                       'legend': 10,
#                       'matter': 46,
#                       'affair': 10,
#                       'permission': 2,
#                       'resignation': 1,
#                       'narrative': 9,
#                       'origin': 2,
#                       'story': 18,
#                       'father': 11,
#                       'belief': 2,
#                       'Justice': 1,
#                       'sin': 1,
#                       'ban': 1,
#                       'prayer': 2,
#                       'repentance': 1,
#                       'past': 1,
#                       'future': 3,
#                       'undoing': 1,
#                       'history': 3,
#                       'attention': 7,
#                       'wanton': 2,
#                       'humour': 2,
#                       'word': 22,
#                       'passion': 4,
#                       'daughter': 3,
#                       'yeoman': 1,
#                       'estate': 7,
#                       'maiden': 4,
#                       'repute': 1,
#                       'farm': 3,
#                       'chamber': 3,
#                       'carouse': 1,
#                       'custom': 2,
#                       'lass': 1,
#                       'singing': 1,
#                       'shouting': 1,
#                       'wine': 4,
#                       'stress': 1,
#                       'fear': 8,
#                       'aid': 5,
#                       'growth': 1,
#                       'ivy': 4,
#                       'wall': 10,
#                       'moor': 154,
#                       'food': 10,
#                       'drink': 2,
#                       'cage': 1,
#                       'bird': 4,
#                       'devil': 10,
#                       'dining': 6,
#                       'hall': 13,
#                       'company': 5,
#                       'body': 18,
#                       'soul': 9,
#                       'wench': 1,
#                       'fury': 3,
#                       'rest': 12,
#                       'mare': 4,
#                       'pack': 1,
#                       'kerchief': 1,
#                       'maid': 6,
#                       'cry': 24,
#                       'moonlight': 4,
#                       'haste': 2,
#                       'deed': 2,
#                       'uproar': 1,
#                       'flask': 2,
#                       'length': 5,
#                       'sense': 7,
#                       'whole': 4,
#                       'number': 8,
#                       'horse': 4,
#                       'pursuit': 7,
#                       'moon': 16,
#                       'course': 18,
#                       'mile': 4,
#                       'track': 14,
#                       'mute': 1,
#                       'hound': 48,
#                       'hell': 6,
#                       'shepherd': 2,
#                       'galloping': 1,
#                       'froth': 1,
#                       'bridle': 1,
#                       'saddle': 1,
#                       'valour': 2,
#                       'breed': 2,
#                       'cluster': 1,
#                       'dip': 2,
#                       'valley': 3,
#                       'halt': 1,
#                       'advance': 1,
#                       'goyal': 1,
#                       'clearing': 1,
#                       'centre': 9,
#                       'fatigue': 1,
#                       'sight': 12,
#                       'hair': 5,
#                       'throat': 8,
#                       'thing': 32,
#                       'beast': 7,
#                       'eye': 7,
#                       'twain': 1,
#                       'tale': 1,
#                       'coming': 3,
#                       'hath': 1,
#                       'terror': 5,
#                       'goodness': 1,
#                       'generation': 1,
#                       'Providence': 1,
#                       'caution': 2,
#                       'evil': 7,
#                       'sister': 18,
#                       'forehead': 3,
#                       'fire': 7,
#                       'collector': 1,
#                       'fairy': 1,
#                       'newspaper': 3,
#                       'year': 3,
#                       'account': 6,
#                       'candidate': 1,
#                       'election': 1,
#                       'gloom': 9,
#                       'county': 8,
#                       'period': 2,
#                       'amiability': 1,
#                       'character': 9,
#                       'generosity': 4,
#                       'affection': 2,
#                       'respect': 3,
#                       'contact': 2,
#                       'nouveaux': 1,
#                       'case': 45,
#                       'scion': 1,
#                       'fortune': 9,
#                       'grandeur': 2,
#                       'money': 5,
#                       'speculation': 2,
#                       'wheel': 2,
#                       'residence': 2,
#                       'talk': 4,
#                       'reconstruction': 1,
#                       'improvement': 1,
#                       'childless': 1,
#                       'desire': 2,
#                       'countryside': 7,
#                       'lifetime': 1,
#                       'profit': 2,
#                       'inquest': 5,
#                       'superstition': 4,
#                       'rise': 4,
#                       'play': 2,
#                       'widower': 1,
#                       'spite': 3,
#                       'wealth': 3,
#                       'couple': 5,
#                       'husband': 13,
#                       'butler': 13,
#                       'wife': 34,
#                       'housekeeper': 1,
#                       'evidence': 14,
#                       'health': 3,
#                       'heart': 30,
#                       'colour': 5,
#                       'breathlessness': 1,
#                       'depression': 2,
#                       'effect': 5,
#                       'bed': 4,
#                       'yew': 3,
#                       'alley': 14,
#                       'day': 50,
#                       'luggage': 4,
#                       'walk': 13,
#                       'cigar': 6,
#                       "o'clock": 9,
#                       'lantern': 1,
#                       'search': 3,
#                       'gate': 19,
#                       'fact': 11,
#                       'thence': 1,
#                       'dealer': 1,
#                       'distance': 13,
#                       'confession': 1,
#                       'violence': 2,
#                       'person': 10,
#                       'distortion': 1,
#                       'patient': 1,
#                       'symptom': 1,
#                       'dyspnoea': 1,
#                       'exhaustion': 3,
#                       'explanation': 12,
#                       'disease': 1,
#                       'coroner': 4,
#                       'jury': 1,
#                       'verdict': 2,
#                       'accordance': 1,
#                       'heir': 10,
#                       'finding': 1,
#                       'tenant': 5,
#                       'kin': 2,
#                       'son': 3,
#                       'view': 10,
#                       'comment': 1,
#                       'anxiety': 3,
#                       'touch': 5,
#                       'article': 6,
#                       'emotion': 6,
#                       'motive': 5,
#                       'inquiry': 5,
#                       'reputation': 4,
#                       'good': 5,
#                       'exception': 1,
#                       'naturalist': 8,
#                       'education': 1,
#                       'chance': 19,
#                       'illness': 1,
#                       'community': 2,
#                       'information': 8,
#                       'evening': 24,
#                       'anatomy': 1,
#                       'breaking': 1,
#                       'point': 20,
#                       'idea': 10,
#                       'creature': 15,
#                       'baying': 2,
#                       'question': 14,
#                       'event': 5,
#                       'gig': 1,
#                       'stare': 2,
#                       'horror': 12,
#                       'glimpse': 8,
#                       'calf': 1,
#                       'drive': 8,
#                       'spot': 9,
#                       'animal': 9,
#                       'incident': 4,
#                       'impression': 9,
#                       'keeping': 1,
#                       'episode': 1,
#                       'tragedy': 9,
#                       'justification': 1,
#                       'advice': 5,
#                       'cause': 6,
#                       'state': 4,
#                       'instant': 30,
#                       'catastrophe': 1,
#                       'discovery': 4,
#                       'groom': 3,
#                       'horseback': 1,
#                       'shape': 7,
#                       'gravel': 4,
#                       'arrival': 4,
#                       'face': 75,
#                       'ground': 17,
#                       'identity': 4,
#                       'injury': 1,
#                       'kind': 13,
#                       'woman': 36,
#                       'whisper': 3,
#                       'Problem': 1,
#                       'shudder': 1,
#                       'thrill': 5,
#                       'glitter': 2,
#                       'sheep': 5,
#                       'hedge': 3,
#                       'strip': 1,
#                       'grass': 7,
#                       'side': 40,
#                       'wicket': 3,
#                       'opening': 5,
#                       'None': 4,
#                       'exit': 1,
#                       'summer': 2,
#                       'path': 27,
#                       'edge': 5,
#                       'ash': 3,
#                       'colleague': 1,
#                       'patch': 2,
#                       'gesture': 2,
#                       'page': 7,
#                       'ere': 1,
#                       'rain': 6,
#                       'realm': 1,
#                       'demon': 2,
#                       'countryman': 1,
#                       'farrier': 1,
#                       'moorland': 4,
#                       'farmer': 1,
#                       'apparition': 4,
#                       'reign': 1,
#                       'district': 4,
#                       'hitherto': 1,
#                       'task': 4,
#                       'footmark': 1,
#                       'breath': 5,
#                       'watch': 2,
#                       'quarter': 3,
#                       'gentleman': 18,
#                       'trustee': 1,
#                       'executor': 1,
#                       'claimant': 1,
#                       'kinsman': 1,
#                       'elder': 1,
#                       'lad': 5,
#                       'strain': 1,
#                       'image': 1,
#                       'picture': 9,
#                       'fever': 2,
#                       'wire': 6,
#                       'morning': 45,
#                       'race': 3,
#                       'place': 47,
#                       'prosperity': 1,
#                       'agency': 4,
#                       'abode': 3,
#                       'theory': 5,
#                       'vestry': 1,
#                       'cab': 20,
#                       'tomorrow': 10,
#                       'help': 12,
#                       'appointment': 9,
#                       'shirt': 3,
#                       'cuff': 1,
#                       'seat': 5,
#                       'look': 5,
#                       'satisfaction': 5,
#                       'action': 6,
#                       'pound': 2,
#                       'shag': 1,
#                       'seclusion': 1,
#                       'solitude': 2,
#                       'concentration': 2,
#                       'particle': 1,
#                       'club': 2,
#                       'sitting': 4,
#                       'lamp': 8,
#                       'haze': 2,
#                       'vision': 1,
#                       'dressing': 3,
#                       'gown': 3,
#                       'armchair': 2,
#                       'clay': 1,
#                       'pipe': 1,
#                       'atmosphere': 3,
#                       'freshness': 1,
#                       'expense': 2,
#                       'showery': 1,
#                       'miry': 1,
#                       'gloss': 1,
#                       'hat': 9,
#                       'fixture': 2,
#                       'contrary': 5,
#                       'spirit': 5,
#                       'absence': 3,
#                       'map': 2,
#                       'portion': 3,
#                       'scale': 1,
#                       'section': 1,
#                       'round': 4,
#                       'right': 10,
#                       'clump': 1,
#                       'hamlet': 2,
#                       'headquarters': 1,
#                       'radius': 1,
#                       'convict': 20,
#                       'prison': 2,
#                       'stage': 1,
#                       'setting': 1,
#                       'flesh': 1,
#                       'blood': 7,
#                       'outset': 1,
#                       'surmise': 2,
#                       'investigation': 4,
#                       'box': 4,
#                       'outcome': 1,
#                       'distinction': 1,
#                       'fool': 1,
#                       'gipsy': 1,
#                       'stroll': 1,
#                       'inclement': 1,
#                       'credit': 2,
#                       'departure': 1,
#                       'violin': 1,
#                       'business': 17,
#                       'advantage': 4,
#                       'interview': 9,
#                       'clock': 5,
#                       'baronet': 40,
#                       'ruddy': 4,
#                       'tweed': 4,
#                       'suit': 5,
#                       'weather': 4,
#                       'assurance': 1,
#                       'bearing': 2,
#                       'thinking': 1,
#                       'joke': 2,
#                       'letter': 29,
#                       'envelope': 2,
#                       'quality': 3,
#                       'address': 7,
#                       'indication': 3,
#                       'hotel': 15,
#                       'sheet': 4,
#                       'foolscap': 2,
#                       'sentence': 3,
#                       'expedient': 1,
#                       'ink': 5,
#                       'thunder': 8,
#                       'meaning': 3,
#                       'rate': 1,
#                       'knowledge': 6,
#                       'present': 6,
#                       'yesterday': 9,
#                       'Capital': 1,
#                       'trade': 3,
#                       'extract': 2,
#                       'industry': 1,
#                       'tariff': 2,
#                       'legislation': 1,
#                       'run': 1,
#                       'value': 4,
#                       'island': 4,
#                       'glee': 1,
#                       'sentiment': 1,
#                       'bit': 4,
#                       'trail': 4,
#                       'note': 5,
#                       'significance': 1,
#                       'doubt': 20,
#                       'amazement': 8,
#                       'negro': 2,
#                       'hobby': 2,
#                       'crest': 2,
#                       'angle': 2,
#                       'curve': 6,
#                       'difference': 2,
#                       'bourgeois': 1,
#                       'type': 4,
#                       'print': 2,
#                       'penny': 2,
#                       'detection': 1,
#                       'leader': 2,
#                       'issue': 2,
#                       'message': 11,
#                       'Nail': 1,
#                       'cutter': 2,
#                       'paste': 2,
#                       'gum': 1,
#                       'effort': 5,
#                       'writing': 4,
#                       'Life': 2,
#                       'carelessness': 1,
#                       'agitation': 2,
#                       'composer': 2,
#                       'hurry': 3,
#                       'interruption': 2,
#                       'region': 2,
#                       'guesswork': 1,
#                       'imagination': 3,
#                       'guess': 1,
#                       'pen': 4,
#                       'writer': 1,
#                       'trouble': 10,
#                       'bottle': 4,
#                       'combination': 2,
#                       'waste': 4,
#                       'water': 5,
#                       'thick': 1,
#                       'dime': 1,
#                       'novel': 1,
#                       'routine': 3,
#                       'chap': 3,
#                       'shopping': 1,
#                       'squire': 1,
#                       'careless': 1,
#                       'boot': 17,
#                       'decision': 3,
#                       'promise': 3,
#                       'request': 2,
#                       'inheritance': 1,
#                       'vengeance': 1,
#                       'nursery': 1,
#                       'uncle': 7,
#                       'policeman': 1,
#                       'clergyman': 2,
#                       'danger': 18,
#                       'fiend': 2,
#                       'answer': 12,
#                       'earth': 12,
#                       'dusky': 1,
#                       'red': 2,
#                       'temper': 2,
#                       'representative': 1,
#                       'lunch': 5,
#                       'bang': 1,
#                       'dreamer': 1,
#                       'street': 5,
#                       'pace': 2,
#                       'half': 11,
#                       'shop': 1,
#                       'hansom': 2,
#                       'beard': 14,
#                       'trapdoor': 1,
#                       'top': 6,
#                       'driver': 5,
#                       'stream': 3,
#                       'traffic': 1,
#                       'start': 1,
#                       'vexation': 2,
#                       'tide': 1,
#                       'luck': 4,
#                       'management': 1,
#                       'spy': 4,
#                       'benevolent': 1,
#                       'design': 2,
#                       'dash': 1,
#                       'notice': 4,
#                       'method': 2,
#                       'disadvantage': 1,
#                       'cabman': 8,
#                       'pity': 4,
#                       'leisure': 1,
#                       'unknown': 2,
#                       'game': 8,
#                       'eagerness': 3,
#                       'quickness': 1,
#                       'energy': 3,
#                       'opponent': 1,
#                       'conversation': 10,
#                       'object': 12,
#                       'shadow': 10,
#                       'save': 1,
#                       'messenger': 3,
#                       'manager': 3,
#                       'recollection': 3,
#                       'ability': 1,
#                       'reverence': 1,
#                       'detective': 9,
#                       'neighbourhood': 2,
#                       'turn': 6,
#                       'porter': 4,
#                       'shilling': 2,
#                       'telegram': 10,
#                       'copy': 1,
#                       'heap': 1,
#                       'report': 11,
#                       'degree': 2,
#                       'art': 2,
#                       'gallery': 4,
#                       'clerk': 1,
#                       'looking': 1,
#                       'register': 1,
#                       'book': 1,
#                       'limp': 1,
#                       'coal': 2,
#                       'curiosity': 3,
#                       'lady': 30,
#                       'mayor': 1,
#                       'acquaintance': 6,
#                       'anger': 5,
#                       'dialect': 1,
#                       'sucker': 1,
#                       'brown': 1,
#                       'black': 2,
#                       'patent': 1,
#                       'waiter': 2,
#                       'scene': 8,
#                       'sundown': 1,
#                       'patience': 3,
#                       'mine': 6,
#                       'den': 1,
#                       'trifle': 2,
#                       'conjunction': 1,
#                       'capital': 2,
#                       'luncheon': 1,
#                       'week': 4,
#                       'city': 1,
#                       'mischief': 2,
#                       'charge': 5,
#                       'ascertain': 1,
#                       'possibility': 3,
#                       'telegraph': 2,
#                       'form': 2,
#                       'Address': 1,
#                       'office': 5,
#                       'postmaster': 5,
#                       'post': 4,
#                       'caretaker': 1,
#                       'legacy': 1,
#                       'residue': 2,
#                       'sum': 1,
#                       'stake': 2,
#                       'settlement': 1,
#                       'title': 2,
#                       'property': 2,
#                       'land': 4,
#                       'advisability': 1,
#                       'delay': 1,
#                       'provision': 1,
#                       'goodwill': 1,
#                       'crisis': 2,
#                       'blackmailer': 1,
#                       'scandal': 3,
#                       'arm': 5,
#                       'proposition': 1,
#                       'adventure': 7,
#                       'fascination': 2,
#                       'train': 4,
#                       'triumph': 5,
#                       'cabinet': 1,
#                       'item': 1,
#                       'purposeless': 1,
#                       'series': 3,
#                       'receipt': 1,
#                       'loss': 4,
#                       'silence': 8,
#                       'scheme': 1,
#                       'afternoon': 5,
#                       'dinner': 8,
#                       'scent': 3,
#                       'bell': 2,
#                       'gent': 1,
#                       'No': 1,
#                       'complaint': 1,
#                       'sovereign': 1,
#                       'mistake': 5,
#                       'grin': 1,
#                       'fare': 3,
#                       'glance': 7,
#                       'reply': 1,
#                       'laugh': 2,
#                       'foil': 1,
#                       'rank': 1,
#                       'trap': 5,
#                       'station': 10,
#                       'height': 3,
#                       'toff': 1,
#                       'Colour': 1,
#                       'shrug': 1,
#                       'thread': 2,
#                       'foeman': 2,
#                       'steel': 2,
#                       'parting': 1,
#                       'manner': 7,
#                       'theorizing': 1,
#                       'disposition': 1,
#                       'persecution': 2,
#                       'injustice': 2,
#                       'list': 1,
#                       'factor': 3,
#                       'folk': 9,
#                       'study': 8,
#                       'revolver': 7,
#                       'class': 2,
#                       'carriage': 5,
#                       'platform': 4,
#                       'news': 3,
#                       'amusement': 3,
#                       'park': 2,
#                       'misfortune': 3,
#                       'queer': 3,
#                       'darkness': 21,
#                       'figure': 16,
#                       'motionless': 1,
#                       'journey': 8,
#                       'brick': 1,
#                       'granite': 11,
#                       'vegetation': 2,
#                       'damper': 1,
#                       'climate': 1,
#                       'delight': 2,
#                       'scenery': 1,
#                       'enthusiasm': 2,
#                       'attachment': 1,
#                       'boy': 16,
#                       'cottage': 2,
#                       'Thence': 2,
#                       'wish': 1,
#                       'hill': 20,
#                       'summit': 6,
#                       'landscape': 2,
#                       'dream': 3,
#                       'sway': 1,
#                       'accent': 1,
#                       'railway': 1,
#                       'descendant': 1,
#                       'pride': 2,
#                       'strength': 2,
#                       'quest': 2,
#                       'comrade': 1,
#                       'risk': 5,
#                       'certainty': 1,
#                       'fence': 1,
#                       'wagonette': 7,
#                       'cobs': 1,
#                       'coachman': 1,
#                       'road': 14,
#                       'Rolling': 1,
#                       'pasture': 1,
#                       'foliage': 1,
#                       'sky': 8,
#                       'sinister': 1,
#                       'moss': 1,
#                       'tongue': 2,
#                       'sun': 9,
#                       'bridge': 1,
#                       'scrub': 1,
#                       'oak': 3,
#                       'fir': 1,
#                       'tinge': 1,
#                       'rattle': 1,
#                       'heath': 1,
#                       'spur': 1,
#                       'statue': 3,
#                       'pedestal': 1,
#                       'soldier': 1,
#                       'rifle': 1,
#                       'forearm': 1,
#                       'cut': 2,
#                       'murderer': 1,
#                       'ferocity': 1,
#                       'brutality': 1,
#                       'assassin': 1,
#                       'commutation': 1,
#                       'sanity': 1,
#                       'conduct': 2,
#                       'expanse': 6,
#                       'cairns': 1,
#                       'wind': 12,
#                       'plain': 3,
#                       'burrow': 2,
#                       'malignancy': 1,
#                       'suggestiveness': 1,
#                       'overcoat': 1,
#                       'plough': 1,
#                       'tangle': 3,
#                       'bleaker': 1,
#                       'russet': 3,
#                       'olive': 1,
#                       'stone': 15,
#                       'creeper': 1,
#                       'outline': 5,
#                       'storm': 1,
#                       'whip': 1,
#                       'lodge': 2,
#                       'maze': 1,
#                       'tracery': 1,
#                       'ruin': 1,
#                       'building': 3,
#                       'fruit': 1,
#                       'gateway': 1,
#                       'avenue': 3,
#                       'tunnel': 2,
#                       'ghost': 2,
#                       'wonder': 4,
#                       'row': 2,
#                       'candle': 15,
#                       'turf': 1,
#                       'block': 3,
#                       'porch': 2,
#                       'bare': 1,
#                       'veil': 2,
#                       'roof': 9,
#                       'column': 1,
#                       'guide': 4,
#                       'apartment': 1,
#                       'fireplace': 1,
#                       'log': 1,
#                       'glass': 5,
#                       'panelling': 2,
#                       ...}),
#              ('CD',
#               'NUM'): Counter({'1': 1,
#                       '1884': 2,
#                       'one': 155,
#                       'two': 73,
#                       'five': 15,
#                       'thirty': 4,
#                       '1882': 3,
#                       '1883': 1,
#                       '2': 1,
#                       '1730': 1,
#                       '1742': 2,
#                       'three': 27,
#                       'twenty': 9,
#                       'four': 10,
#                       'six': 4,
#                       'thirteen': 1,
#                       'One': 18,
#                       '14th': 1,
#                       'twelve': 3,
#                       '3': 2,
#                       'eight': 2,
#                       'fifty': 3,
#                       'ten': 12,
#                       '1876': 1,
#                       'Twenty': 1,
#                       'Three': 2,
#                       'nine': 2,
#                       'fourteen': 2,
#                       '4': 1,
#                       'eleven': 1,
#                       'hundred': 9,
#                       '2704': 3,
#                       '5': 1,
#                       'thousand': 4,
#                       'Seven': 1,
#                       'forty': 5,
#                       'million': 1,
#                       'seven': 2,
#                       '6': 1,
#                       'Two': 3,
#                       '7': 1,
#                       "mare's": 1,
#                       '8': 1,
#                       '9': 1,
#                       '10': 1,
#                       '11': 1,
#                       '200': 1,
#                       '12': 1,
#                       '13': 1,
#                       '1647': 1,
#                       '66': 1,
#                       '14': 1}),
#              ('NNP',
#               'PROPN'): Counter({'Mr.': 62,
#                       'Sherlock': 33,
#                       'Holmes': 162,
#                       'Penang': 1,
#                       'James': 10,
#                       'Mortimer': 78,
#                       'M.R.C.S.': 2,
#                       'C.C.H.': 2,
#                       'Watson': 112,
#                       'Dr.': 100,
#                       'Excellent': 5,
#                       'C.C.H': 1,
#                       'Something': 1,
#                       'Hunt': 1,
#                       'C.C.': 1,
#                       'Charing': 7,
#                       'Cross': 7,
#                       'Hospital': 3,
#                       'London': 40,
#                       'Medical': 2,
#                       'Directory': 2,
#                       'Grimpen': 19,
#                       'Dartmoor': 5,
#                       'Devon': 4,
#                       'surgeon': 1,
#                       'Jackson': 1,
#                       'Comparative': 1,
#                       'Pathology': 1,
#                       'Disease': 1,
#                       'Reversion': 1,
#                       'Swedish': 1,
#                       'Pathological': 1,
#                       'Society': 1,
#                       'Freaks': 1,
#                       'Atavism': 1,
#                       'Lancet': 1,
#                       'Journal': 1,
#                       'Psychology': 1,
#                       'March': 1,
#                       'Officer': 1,
#                       'Thorsley': 1,
#                       'High': 3,
#                       'Barrow': 1,
#                       'Jove': 2,
#                       'Shipping': 1,
#                       'Office': 1,
#                       'Mister': 1,
#                       'M.R.C.S': 1,
#                       'Europe': 1,
#                       'Monsieur': 1,
#                       'Bertillon': 1,
#                       'Curse': 1,
#                       'Sir': 230,
#                       'Charles': 87,
#                       'Baskerville': 105,
#                       'Devonshire': 8,
#                       'Hall': 54,
#                       'Hound': 5,
#                       'Hugo': 16,
#                       'Great': 1,
#                       'Rebellion': 1,
#                       'Lord': 1,
#                       'Clarendon': 1,
#                       'Manor': 1,
#                       'West': 4,
#                       'Michaelmas': 1,
#                       'Evil': 2,
#                       'Whereat': 1,
#                       'God': 16,
#                       'Providence': 1,
#                       'Holy': 1,
#                       'Writ': 1,
#                       'Rodger': 4,
#                       'John': 6,
#                       'Elizabeth': 1,
#                       'County': 2,
#                       'Chronicle': 1,
#                       'May': 2,
#                       'Mid': 1,
#                       'England': 9,
#                       'Barrymore': 73,
#                       'Murphy': 1,
#                       'Henry': 144,
#                       'America': 4,
#                       'Vatican': 1,
#                       'Pope': 1,
#                       'Frankland': 18,
#                       'Lafter': 5,
#                       'Stapleton': 65,
#                       'South': 3,
#                       'Africa': 1,
#                       'Bushman': 1,
#                       'Hottentot': 1,
#                       'Perkins': 5,
#                       'heaven': 5,
#                       'Nature': 4,
#                       'Father': 1,
#                       'Waterloo': 5,
#                       'Station': 4,
#                       'Canada': 2,
#                       'Central': 1,
#                       'Baskervilles': 9,
#                       'Southampton': 1,
#                       'Bradley': 2,
#                       'Baker': 11,
#                       'Street': 24,
#                       'Stamford': 1,
#                       'Ordnance': 1,
#                       'Tor': 6,
#                       'Foulmire': 2,
#                       'Princetown': 5,
#                       'Northumberland': 7,
#                       'Hotel': 8,
#                       'Hum': 1,
#                       'Times': 9,
#                       'Doctor': 1,
#                       'Esquimau': 2,
#                       'Leeds': 1,
#                       'Mercury': 1,
#                       'Western': 1,
#                       'Morning': 1,
#                       'News': 1,
#                       'Halloa': 7,
#                       'States': 1,
#                       'Strand': 1,
#                       'Au': 1,
#                       'revoir': 1,
#                       'Oxford': 3,
#                       'Regent': 8,
#                       'Wilson': 2,
#                       'Cartwright': 6,
#                       'Bond': 1,
#                       'Broken': 1,
#                       'Theophilus': 1,
#                       'Johnson': 3,
#                       'Newcastle': 1,
#                       'Mrs.': 27,
#                       'Oldmore': 2,
#                       'Lodge': 1,
#                       'Alton': 1,
#                       'Gloucester': 1,
#                       'Telegram': 1,
#                       'Desmond': 3,
#                       'Westmoreland': 1,
#                       'Saturday': 2,
#                       'Paddington': 1,
#                       'German': 1,
#                       'CARTWRIGHT': 1,
#                       'Official': 1,
#                       'Registry': 1,
#                       'Yard': 2,
#                       'Clayton': 3,
#                       'Turpey': 1,
#                       'Borough': 1,
#                       'Shipley': 1,
#                       'Trafalgar': 1,
#                       'Square': 1,
#                       'Museum': 1,
#                       'College': 1,
#                       'Surgeons': 1,
#                       'Young': 1,
#                       'Celt': 1,
#                       'Poor': 2,
#                       'Gaelic': 1,
#                       'Coast': 1,
#                       "hart's": 1,
#                       'Yellow': 1,
#                       'Selden': 13,
#                       'Notting': 2,
#                       'Hill': 2,
#                       'Swan': 1,
#                       'Edison': 1,
#                       'Elizabethan': 1,
#                       'Regency': 1,
#                       'Merripit': 13,
#                       'House': 13,
#                       'Mire': 10,
#                       'George': 1,
#                       'Cyclopides': 2,
#                       'Miss': 11,
#                       'Hush': 3,
#                       'Beryl': 2,
#                       'Jack': 1,
#                       'Lepidoptera': 1,
#                       'Report': 2,
#                       'October': 4,
#                       'Thursday': 1,
#                       'Long': 2,
#                       'Fernworthy': 3,
#                       'Neolithic': 2,
#                       'Light': 1,
#                       'Moor': 2,
#                       'Oct.': 1,
#                       'Plymouth': 1,
#                       'Friday': 1,
#                       'Eliza': 1,
#                       'Cleft': 1,
#                       'hound': 2,
#                       'Diary': 1,
#                       'L.': 10,
#                       'L': 2,
#                       'Coombe': 15,
#                       'Tracey': 15,
#                       'Laura': 9,
#                       'Lyons': 18,
#                       'Old': 1,
#                       'Man': 1,
#                       'Remington': 1,
#                       'Black': 2,
#                       'Luck': 1,
#                       'Middleton': 1,
#                       'Morland': 2,
#                       'Court': 1,
#                       'Queen': 1,
#                       'Bench': 1,
#                       'Constabulary': 1,
#                       'Regina': 2,
#                       'Belliver': 1,
#                       'Vixen': 1,
#                       'Hark': 1,
#                       'Heaven': 1,
#                       'Resisting': 1,
#                       'Kneller': 1,
#                       'Reynolds': 1,
#                       'Rear': 1,
#                       'Admiral': 1,
#                       'Rodney': 1,
#                       'William': 1,
#                       'Chairman': 1,
#                       'Pitt': 1,
#                       'Road': 1,
#                       'Lestrade': 10,
#                       'York': 1,
#                       'Vandeleur': 2,
#                       'St.': 1,
#                       'Oliver': 1,
#                       'Godno': 1,
#                       'Russia': 1,
#                       'Anderson': 1,
#                       'North': 1,
#                       'Carolina': 1,
#                       'Phosphorus': 1,
#                       'Rank': 1,
#                       'Toronto': 1}),
#              ('WP',
#               'PRON'): Counter({'who': 131,
#                       'what': 118,
#                       'What': 77,
#                       'whom': 28,
#                       'Who': 9,
#                       'Whichever': 1,
#                       'Whom': 1,
#                       'Whatever': 1}),
#              ('VBD',
#               'VERB'): Counter({'was': 165,
#                       'stood': 30,
#                       'picked': 3,
#                       'said': 215,
#                       'gave': 27,
#                       'earned': 1,
#                       'took': 32,
#                       'examined': 4,
#                       'laid': 5,
#                       'looked': 45,
#                       'returned': 9,
#                       'escaped': 6,
#                       'asked': 39,
#                       'were': 44,
#                       'stimulated': 1,
#                       'meant': 9,
#                       'withdrew': 2,
#                       'left': 19,
#                       'laughed': 4,
#                       'leaned': 7,
#                       'blew': 1,
#                       'turned': 29,
#                       'spoke': 11,
#                       'halted': 3,
#                       'glanced': 8,
#                       'jutted': 2,
#                       'frayed': 1,
#                       'walked': 16,
#                       'entered': 6,
#                       'fell': 11,
#                       'ran': 22,
#                       'blinked': 1,
#                       'married': 2,
#                       'covet': 1,
#                       'waved': 2,
#                       'drew': 10,
#                       'twirled': 1,
#                       'had': 82,
#                       'showed': 19,
#                       'came': 68,
#                       'recognized': 3,
#                       'observed': 1,
#                       'put': 15,
#                       'stretched': 2,
# ...
#                       'smouldering': 1,
#                       'flickering': 1,
#                       'leaping': 1,
#                       'hunting': 1,
#                       'pawing': 1,
#                       'sniffing': 1,
#                       'guiding': 1,
#                       'tugging': 1,
#                       'projecting': 1,
#                       'using': 1,
#                       'clutching': 1,
#                       'crumbling': 1,
#                       'surrounding': 1,
#                       'adhering': 1}),
#              ('UH',
#               'INTJ'): Counter({'Well': 56,
#                       'Good': 4,
#                       'No': 62,
#                       'no': 17,
#                       'yes': 3,
#                       'Yes': 57,
#                       'like': 3,
#                       'Oh': 11,
#                       'right': 2,
#                       'please': 6,
#                       'Gum': 1,
#                       'well': 4,
#                       'Ah': 5,
#                       'halloa': 1,
#                       'Ha': 5,
#                       'sorry': 1,
#                       'bye': 3,
#                       'Welcome': 1,
#                       'Now': 1,
#                       'Please': 4,
#                       'eh': 2,
#                       'ha': 1,
#                       'madam': 1}),
#              ('VBP',
#               'AUX'): Counter({'do': 87,
#                       'have': 230,
#                       'am': 55,
#                       'are': 144,
#                       'Do': 19,
#                       'Am': 2,
#                       'Have': 9,
#                       've': 21,
#                       'Are': 6,
#                       'need': 2,
#                       'dare': 1}),
#              ('VBP',
#               'VERB'): Counter({'believe': 6,
#                       'have': 85,
#                       'think': 47,
#                       'know': 46,
#                       'excel': 1,
#                       'are': 46,
#                       'confess': 7,
#                       'trust': 6,
#                       'suggest': 3,
#                       'take': 2,
#                       'read': 3,
#                       'remember': 9,
#                       'see': 23,
#                       'beg': 6,
#                       'hear': 5,
#                       'say': 18,
#                       'presume': 10,
#                       'interest': 2,
#                       'perceive': 3,
#                       'am': 24,
#                       'observe': 2,
#                       'make': 6,
#                       'Have': 6,
#                       'do': 14,
#                       'stand': 1,
#                       'demand': 1,
#                       'understand': 10,
#                       'wish': 9,
#                       'come': 7,
#                       'commend': 2,
#                       'hath': 1,
#                       'forbid': 1,
#                       'call': 2,
#                       'counsel': 1,
#                       'go': 7,
#                       'be': 2,
#                       'live': 2,
#                       'mention': 3,
#                       'mean': 3,
#                       'find': 5,
#                       'tell': 16,
#                       'assure': 10,
#                       'hold': 3,
#                       'desire': 2,
#                       'speak': 2,
#                       'meet': 3,
#                       'feel': 8,
#                       'fear': 8,
#                       'bring': 1,
#                       'put': 2,
#                       'recommend': 1,
#                       'Thank': 8,
#                       'turn': 1,
#                       'pass': 2,
#                       'suppose': 8,
#                       'possess': 1,
#                       'regret': 2,
#                       'flatter': 1,
#                       'fancy': 1,
#                       'value': 2,
#                       'leave': 3,
#                       'promise': 3,
#                       'keep': 1,
#                       "'re": 4,
#                       'want': 6,
#                       'incline': 1,
#                       'balance': 1,
#                       'examine': 1,
#                       'seem': 6,
#                       'hope': 7,
#                       'return': 2,
#                       'share': 1,
#                       'warn': 1,
#                       'descend': 1,
#                       'fail': 1,
#                       'gather': 1,
#                       'exaggerate': 1,
#                       'thank': 4,
#                       'look': 3,
#                       'reach': 1,
#                       'vanish': 1,
#                       'try': 1,
#                       'dare': 6,
#                       'end': 1,
#                       'm': 3,
#                       'like': 4,
#                       'give': 4,
#                       'remain': 2,
#                       'dim': 2,
#                       'watch': 1,
#                       'get': 2,
#                       'Welcome': 1,
#                       'guess': 3,
#                       'engage': 1,
#                       'propose': 2,
#                       'need': 2,
#                       'tire': 1,
#                       'notice': 1,
#                       'wander': 2,
#                       'ask': 2,
#                       'imagine': 1,
#                       'manage': 1,
#                       'round': 2,
#                       'lie': 1,
#                       'show': 1,
#                       'walk': 1,
#                       'sleep': 1,
#                       'dine': 1,
#                       'tear': 1,
#                       'surround': 1,
#                       'wonder': 3,
#                       'suspect': 1,
#                       'fast': 1,
#                       'become': 1,
#                       'name': 1,
#                       'expect': 3,
#                       'prairie': 1,
#                       'hurt': 1,
#                       'start': 2,
#                       'proceed': 1,
#                       'rise': 1,
#                       'bless': 1,
#                       'well': 1,
#                       'swear': 3,
#                       'pink': 1,
#                       'repeat': 2,
#                       'owe': 3,
#                       'answer': 1,
#                       'acknowledge': 2,
#                       'deny': 1,
#                       'cross': 1,
#                       'abhor': 1,
#                       'slap': 1,
#                       'act': 1,
#                       'bind': 1,
#                       'venture': 1,
#                       'set': 1,
#                       'unite': 1,
#                       'use': 1,
#                       'write': 1,
#                       'crumble': 1,
#                       'appreciate': 1,
#                       'add': 1,
#                       'insist': 1,
#                       'intend': 1,
#                       'arrive': 1,
#                       'regard': 1,
#                       'lay': 2,
#                       'bear': 1}),
#              ('JJS',
#               'ADJ'): Counter({'least': 16,
#                       'most': 6,
#                       'highest': 1,
#                       'bravest': 1,
#                       'boldest': 1,
#                       'worst': 3,
#                       'youngest': 1,
#                       'strongest': 3,
#                       'deepest': 1,
#                       'best': 9,
#                       'maddest': 1,
#                       'queerest': 1,
#                       'nearest': 2,
#                       'fullest': 1,
#                       'weirdest': 1,
#                       'strangest': 1,
#                       'farthest': 2,
#                       'latest': 1,
#                       'Best': 1,
#                       'wisest': 1,
#                       'surest': 1,
#                       'stoniest': 1,
#                       'darkest': 1,
#                       'greatest': 2,
#                       'frankest': 1,
#                       'kindest': 1,
#                       'biggest': 1,
#                       'slightest': 1}),
#              ('POS', 'PART'): Counter({"'s": 148}),
#              ('VBZ',
#               'VERB'): Counter({'becomes': 4,
#                       'does': 7,
#                       'gives': 5,
#                       'walks': 2,
#                       'lies': 4,
#                       'seems': 20,
#                       'vanishes': 1,
#                       'emerges': 1,
#                       'is': 121,
#                       'receives': 1,
#                       'abandons': 1,
#                       'leaves': 2,
#                       'has': 26,
#                       'appears': 6,
#                       'runs': 3,
#                       'punishes': 1,
#                       'covers': 1,
#                       'goes': 10,
#                       'turns': 1,
#                       'tends': 1,
#                       'points': 1,
#                       'shows': 2,
#                       'leads': 4,
#                       'declares': 1,
#                       'presents': 2,
#                       'contains': 3,
#                       'shrinks': 1,
#                       'says': 2,
#                       'assumes': 1,
#                       'corresponds': 1,
#                       'arrives': 1,
#                       'meets': 1,
#                       'depends': 4,
#                       'makes': 2,
#                       'comes': 5,
#                       'returns': 2,
#                       'observes': 1,
#                       'concerns': 1,
#                       'extends': 1,
#                       'helps': 2,
#                       'takes': 3,
#                       'wants': 3,
#                       'stands': 1,
#                       'knows': 3,
#                       'exceeds': 1,
#                       'suggests': 2,
#                       'opens': 1,
#                       'cleans': 1,
#                       "'s": 7,
#                       'fits': 2,
#                       'strikes': 3,
#                       'cuts': 2,
#                       'puts': 2,
#                       'remains': 2,
#                       'settles': 1,
#                       'finds': 2,
#                       'means': 7,
#                       'Seems': 1,
#                       'guides': 1,
#                       'likes': 1,
#                       'reveals': 1,
#                       'carries': 1,
#                       'dogs': 1,
#                       'suits': 1,
#                       'sleeps': 1,
#                       'haunts': 2,
#                       'Has': 1,
#                       'follows': 2,
#                       'brings': 3,
#                       'rains': 1,
#                       'thinks': 2,
#                       'stays': 1,
#                       'begins': 1,
#                       'hangs': 1,
#                       'forms': 2,
#                       'fills': 3,
#                       'lives': 2,
#                       'fights': 1,
#                       'applies': 1,
#                       'sweeps': 1,
#                       'intends': 1,
#                       'commands': 1,
#                       'enables': 1,
#                       'pays': 1,
#                       'passes': 3,
#                       'branches': 1,
#                       'ends': 1,
#                       'speaks': 1,
#                       'rests': 1,
#                       'watches': 1,
#                       'hopes': 2,
#                       'dares': 1,
#                       'hills': 1,
#                       'needs': 3,
#                       'offers': 1,
#                       'considers': 1,
#                       'allows': 1,
#                       'alarms': 1,
#                       'huts': 1,
#                       'works': 1,
#                       'calls': 1,
#                       'lurks': 1,
#                       'deceives': 1,
#                       'dreads': 1,
#                       'exists': 1,
#                       'thins': 1,
#                       'possesses': 1,
#                       'shines': 1,
#                       'moths': 1,
#                       'reeds': 1}),
#              ('MD',
#               'AUX'): Counter({'could': 184,
#                       'can': 117,
#                       'should': 134,
#                       'may': 86,
#                       'must': 82,
#                       'would': 167,
#                       'might': 75,
#                       'will': 160,
#                       'Would': 5,
#                       'May': 3,
#                       "'ll": 27,
#                       'Might': 2,
#                       'shall': 35,
#                       'ca': 11,
#                       'Shall': 4,
#                       "'d": 3,
#                       'Could': 4,
#                       'wo': 3,
#                       'ought': 3,
#                       'Can': 5,
#                       'Will': 2}),
#              ('VBN', 'AUX'): Counter({'been': 88}),
#              ('EX', 'PRON'): Counter({'there': 133, 'There': 93}),
#              ('WP$', 'DET'): Counter({'whose': 6}),
#              ('NN',
#               'PRON'): Counter({'anything': 33,
#                       'nothing': 53,
#                       'something': 38,
#                       'Everything': 2,
#                       'anyone': 18,
#                       'nobody': 1,
#                       'someone': 14,
#                       'Nothing': 7,
#                       'Someone': 2,
#                       'everyone': 2,
#                       'everything': 9,
#                       'Anything': 2,
#                       'Something': 3,
#                       'somebody': 2,
#                       'Somebody': 1}),
#              ('RBR',
#               'ADV'): Counter({'more': 69,
#                       'farther': 2,
#                       'better': 9,
#                       'later': 1,
#                       'More': 1,
#                       'less': 4,
#                       'sooner': 4,
#                       'louder': 4,
#                       'lower': 1,
#                       'wider': 1,
#                       'earlier': 2,
#                       'nearer': 3,
#                       'closer': 3,
#                       'longer': 1}),
#              ('RBS', 'ADV'): Counter({'most': 42, 'Most': 3, 'least': 1}),
#              ('VB',
#               'AUX'): Counter({'be': 79,
#                       'have': 134,
#                       'Do': 3,
#                       'Pray': 1,
#                       'do': 3,
#                       'get': 1}),
#              ('JJR',
#               'ADJ'): Counter({'more': 59,
#                       'larger': 3,
#                       'smaller': 1,
#                       'terrier': 1,
#                       'worse': 3,
#                       'less': 7,
#                       'younger': 3,
#                       'higher': 2,
#                       'older': 2,
#                       'broader': 1,
#                       'better': 15,
#                       'shorter': 2,
#                       'greater': 4,
#                       'richer': 1,
#                       'lower': 6,
#                       'stronger': 1,
#                       'darker': 1,
#                       'longer': 1,
#                       'lighter': 2,
#                       'clearer': 1,
#                       'closer': 1,
#                       'elder': 1,
#                       'safer': 1,
#                       'taller': 2,
#                       'thinner': 1,
#                       'wiser': 1,
#                       'easier': 1,
#                       'firmer': 1}),
#              ('NNPS',
#               'PROPN'): Counter({'Mortimers': 1,
#                       'Holmes': 1,
#                       'Baskervilles': 3,
#                       'Powers': 1,
#                       'Barrymores': 5,
#                       'Times': 1,
#                       'Desmonds': 1,
#                       'Stapletons': 11,
#                       'Nets': 1,
#                       'Indies': 1,
#                       'Committees': 1,
#                       'Commons': 1}),
#              ('VBG',
#               'AUX'): Counter({'being': 7,
#                       'having': 8,
#                       'standing': 1,
#                       'becoming': 1,
#                       'glancing': 1,
#                       'lying': 1,
#                       'Having': 1}),
#              ('POS', 'AUX'): Counter({"'s": 1}),
#              ('IN', 'AUX'): Counter({'by': 1, 'to': 1})})
