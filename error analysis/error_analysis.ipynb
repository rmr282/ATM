# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
pred_df = pd.read_csv('predictions_validation.csv')
val_df = pd.read_csv('SEM2012_validation_data_with_features.csv')

# %%
val_df = val_df[pred_df_cols]
val_df['prediction'] = pred_df['prediction']
# Out:
# /var/folders/h3/7t_9rx413hz822w3tl1gnxh40000gn/T/ipykernel_38183/767335912.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_df['prediction'] = pred_df['prediction']

# %%
diff = val_df.loc[val_df['label']!= val_df['prediction']]
diff.to_csv("diff_val_pred.csv")

# %%
diff
# Out:
#                lemma   pos snowball_stemmer porter_stemmer  \
# 329         improper   ADJ           improp         improp
# 386             none  NOUN             none           none
# 431        unbrushed   ADJ          unbrush        unbrush
# 434         unshaven   ADJ         unshaven       unshaven
# 511        unbrushed   ADJ          unbrush        unbrush
# 512          unkempt  VERB          unkempt        unkempt
# 527   unconventional   ADJ        unconvent      unconvent
# 638               no  INTJ               no             no
# 1085      impatience  NOUN           impati         impati
# 1168         endless   ADJ          endless        endless
# 1620        unburned   ADJ           unburn         unburn
# 1751     undoubtedly   ADV          undoubt    undoubtedli
# 1931      uncommonly   ADV         uncommon     uncommonli
# 2052              no  INTJ               no             no
# 2633  irreproachable   ADJ       irreproach     irreproach
# 2678      insensibly   ADV           insens         insens
# 2762    inadmissable   ADJ         inadmiss       inadmiss
# 2797    insufferable   ADJ         insuffer       insuffer
# 2877              no  INTJ               no             no
# 3962            none  NOUN             none           none
# 4033            save  VERB             save           save
# 4122      dissatisfy  VERB       dissatisfi     dissatisfi
# 4658            none  NOUN             none           none
# 5054     undoubtedly   ADV          undoubt    undoubtedli
# 5237         dislike  NOUN           dislik         dislik
# 5743      listlessly   ADV         listless     listlessli
# 6348              no  INTJ               no             no
# 6401           never   ADV            never          never
# 7049            more   ADJ             more           more
# 7226              no  INTJ               no             no
# 7337         unclean   ADJ          unclean        unclean
#
#       is_part_of_negation  has_prefix  has_postfix  has_infix  label  \
# 329                     0        True        False      False  B-NEG
# 386                     0       False        False      False      O
# 431                     0        True        False      False  B-NEG
# 434                     0        True        False      False  B-NEG
# 511                     0        True        False      False  B-NEG
# 512                     0        True        False      False  B-NEG
# 527                     0        True        False      False  B-NEG
# 638                     0       False        False      False      O
# 1085                    0        True        False      False  B-NEG
# 1168                    0       False         True      False      O
# 1620                    0        True        False      False  B-NEG
# 1751                    0        True        False      False  B-NEG
# 1931                    0        True        False      False  B-NEG
# 2052                    0       False        False      False      O
# 2633                    0        True        False      False  B-NEG
# 2678                    0        True        False      False  B-NEG
# 2762                    0        True        False      False  B-NEG
# 2797                    0        True        False      False  B-NEG
# 2877                    0       False        False      False      O
# 3962                    0       False        False      False      O
# 4033                    0       False        False      False  B-NEG
# 4122                    0        True        False      False  B-NEG
# 4658                    0       False        False      False      O
# 5054                    0        True        False      False  B-NEG
# 5237                    0        True        False      False  B-NEG
# 5743                    0       False        False       True      O
# 6348                    0       False        False      False      O
# 6401                    0       False        False      False      O
# 7049                    1       False        False      False  I-NEG
# 7226                    0       False        False      False      O
# 7337                    0        True        False      False  B-NEG
#
#      prediction
# 329           O
# 386       B-NEG
# 431           O
# 434           O
# 511           O
# 512           O
# 527           O
# 638       B-NEG
# 1085          O
# 1168      B-NEG
# 1620          O
# 1751          O
# 1931          O
# 2052      B-NEG
# 2633          O
# 2678          O
# 2762          O
# 2797          O
# 2877      B-NEG
# 3962      B-NEG
# 4033          O
# 4122          O
# 4658      B-NEG
# 5054          O
# 5237          O
# 5743      B-NEG
# 6348      B-NEG
# 6401      B-NEG
# 7049          O
# 7226      B-NEG
# 7337          O

# %%
first_try = diff.loc[diff['prediction']=='O']

# %%
len(first_try)
# Out:
# 20

# %%
first_try
# Out:
#                lemma   pos snowball_stemmer porter_stemmer  \
# 329         improper   ADJ           improp         improp
# 431        unbrushed   ADJ          unbrush        unbrush
# 434         unshaven   ADJ         unshaven       unshaven
# 511        unbrushed   ADJ          unbrush        unbrush
# 512          unkempt  VERB          unkempt        unkempt
# 527   unconventional   ADJ        unconvent      unconvent
# 1085      impatience  NOUN           impati         impati
# 1620        unburned   ADJ           unburn         unburn
# 1751     undoubtedly   ADV          undoubt    undoubtedli
# 1931      uncommonly   ADV         uncommon     uncommonli
# 2633  irreproachable   ADJ       irreproach     irreproach
# 2678      insensibly   ADV           insens         insens
# 2762    inadmissable   ADJ         inadmiss       inadmiss
# 2797    insufferable   ADJ         insuffer       insuffer
# 4033            save  VERB             save           save
# 4122      dissatisfy  VERB       dissatisfi     dissatisfi
# 5054     undoubtedly   ADV          undoubt    undoubtedli
# 5237         dislike  NOUN           dislik         dislik
# 7049            more   ADJ             more           more
# 7337         unclean   ADJ          unclean        unclean
#
#       is_part_of_negation  has_prefix  has_postfix  has_infix  label  \
# 329                     0        True        False      False  B-NEG
# 431                     0        True        False      False  B-NEG
# 434                     0        True        False      False  B-NEG
# 511                     0        True        False      False  B-NEG
# 512                     0        True        False      False  B-NEG
# 527                     0        True        False      False  B-NEG
# 1085                    0        True        False      False  B-NEG
# 1620                    0        True        False      False  B-NEG
# 1751                    0        True        False      False  B-NEG
# 1931                    0        True        False      False  B-NEG
# 2633                    0        True        False      False  B-NEG
# 2678                    0        True        False      False  B-NEG
# 2762                    0        True        False      False  B-NEG
# 2797                    0        True        False      False  B-NEG
# 4033                    0       False        False      False  B-NEG
# 4122                    0        True        False      False  B-NEG
# 5054                    0        True        False      False  B-NEG
# 5237                    0        True        False      False  B-NEG
# 7049                    1       False        False      False  I-NEG
# 7337                    0        True        False      False  B-NEG
#
#      prediction
# 329           O
# 431           O
# 434           O
# 511           O
# 512           O
# 527           O
# 1085          O
# 1620          O
# 1751          O
# 1931          O
# 2633          O
# 2678          O
# 2762          O
# 2797          O
# 4033          O
# 4122          O
# 5054          O
# 5237          O
# 7049          O
# 7337          O

# %%
val_df
# Out:
#            lemma    pos snowball_stemmer porter_stemmer  is_part_of_negation  \
# 0              1      X               1.             1.                    0
# 1            the    DET              the            the                    0
# 2       singular   VERB         singular       singular                    0
# 3     experience   NOUN           experi         experi                    0
# 4             mr  PROPN              mr.            mr.                    0
# ...          ...    ...              ...            ...                  ...
# 7370      savage   VERB            savag          savag                    0
# 7371      friend   NOUN           friend         friend                    0
# 7372          be    AUX              was             wa                    0
# 7373    orthodox  PROPN         orthodox       orthodox                    0
# 7374      ritual    ADJ           ritual         ritual                    0
#
#       has_prefix  has_postfix  has_infix label prediction
# 0          False        False      False     O          O
# 1          False        False      False     O          O
# 2          False        False      False     O          O
# 3          False        False      False     O          O
# 4          False        False      False     O          O
# ...          ...          ...        ...   ...        ...
# 7370       False        False      False     O          O
# 7371       False        False      False     O          O
# 7372       False        False      False     O          O
# 7373       False        False      False     O          O
# 7374       False        False      False     O          O
#
# [7375 rows x 10 columns]

# %%
B_NEG_val = val_df.loc[val_df['label']=='B-NEG']
I_NEG_val  = val_df.loc[val_df['label']=='I-NEG']

# %%
B_NEG['lemma'].unique()
# Out:
# array(['no', 'unpleasant', 'never', 'improper', 'without', 'unbrushed',
#        'unshaven', 'unkempt', 'unconventional', 'not', 'impatience',
#        'neither', 'nor', 'nothing', 'unknown', 'unburned', 'undoubtedly',
#        'uncommonly', 'impossible', 'unmistakable', 'by', 'unnatural',
#        'irreproachable', 'insensibly', 'inadmissable', 'insufferable',
#        'needless', 'save', 'dissatisfy', 'inexplicable', 'sapless',
#        'dislike', 'nobody', 'invisible', 'fearless', 'unclean'],
#       dtype=object)

# %%
len(B_NEG)
# Out:
# 134

# %%
I_NEG
# Out:
#      lemma   pos snowball_stemmer porter_stemmer  is_part_of_negation  \
# 2135    no  INTJ               no             no                    1
# 2136  mean  VERB             mean           mean                    1
# 7049  more   ADJ             more           more                    1
#
#       has_prefix  has_postfix  has_infix  label prediction
# 2135       False        False      False  I-NEG      I-NEG
# 2136       False        False      False  I-NEG      I-NEG
# 7049       False        False      False  I-NEG          O

# %%
B_NEG_pred = val_df.loc[val_df['prediction']=='B-NEG']
I_NEG_pred  = val_df.loc[val_df['prediction']=='I-NEG']

# %%
I_NEG_pred
# Out:
#      lemma   pos snowball_stemmer porter_stemmer  is_part_of_negation  \
# 2135    no  INTJ               no             no                    1
# 2136  mean  VERB             mean           mean                    1
#
#       has_prefix  has_postfix  has_infix  label prediction
# 2135       False        False      False  I-NEG      I-NEG
# 2136       False        False      False  I-NEG      I-NEG

# %%
len(B_NEG_pred['lemma'].unique())
# Out:
# 22

# %%
len(B_NEG_pred)
# Out:
# 126
